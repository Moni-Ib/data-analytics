# %%
from sklearn.datasets import make_regression

# %%
X, y= make_regression(n_features=1, noise=30, random_state=0) #randomstate es el estado aleatorio, para que los datos sean lo mismo cada vez

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
import pandas as pd 
df=pd.DataFrame(X)
df.columns = ["x"]
df["y"]=y
df
# Out:
#            x          y
# 0  -0.359553 -29.387972
# 1   0.976639 -18.771359
# 2   0.402342   0.563777
# 3  -0.813146  19.905024
# 4  -0.887786 -31.843421
# ..       ...        ...
# 95 -1.165150 -46.555436
# 96 -0.362741  29.346690
# 97  0.356366   5.143858
# 98 -1.613898 -21.482798
# 99 -1.180632 -66.176710
#
# [100 rows x 2 columns]

# %%
df["x"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.pyplot as plt #clase el tipo de modelo

model_1=LinearRegression() #quiero un objeto de tipo linearRegression
model_2=LinearRegression()
model_3=LinearRegression()

model_1.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model_1.predict(X)

# %%
import numpy as np

y_mean=np.array([y.mean()]*100)

# %%
y.mean()
# Out:
# 0.1344193000112442

# %%
#Selector
plt.figure(figsize=(10,4)) #tamaño de la gráfica

#Data
plt.scatter(X,y, label="Random data")

plt.plot(X,y_mean, label="Mean", c="green")

plt.plot(X,y_pred, label="Linear Regression", c="red")

#show 
plt.xlabel("Feature")
plt.ylabel("Target (y)")
plt.title("Scatter example plot")
plt.legend()

plt.savefig("../reports/figures/random1.svg")

# %% [markdown]
# # Activity
#
# Dataset: Boston Housing
#
# X: Top-1 correlate feature with target
#
# Target: MEDV
#
# Model: Linear Regression

# %%
df= pd.read_csv("C:/Users/cesar/apps/data-analytics/data/raw/BostonHousing.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
modelo_bh= LinearRegression()
x2= np.array(df['lstat']).reshape(-1,1)
y2= np.array(df['medv']).reshape(-1,1)
modelo_bh.fit(x2,y2)
# Out:
# LinearRegression()

# %%
y_pred2=modelo_bh.predict(x2)

# %%
plt.figure(figsize=(10,4))

# Data
plt.scatter(x2,y2, label='Data')

plt.plot(x2, y_pred2, label='Linear Regression',c='green')

plt.xlabel('lstat')
plt.ylabel('medv')
plt.legend()
plt.title('Mónica Ibarra Herrera')
plt.savefig("../reports/figures/randomBoston.png")
