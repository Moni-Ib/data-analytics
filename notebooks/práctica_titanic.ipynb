# %% [markdown]
# # Práctica Titanic

# %% [markdown]
# Mónica Ibarra Herrera

# %%
# !pip install pandas

# %%
import pandas as pd

path = "C:/Users/cesar/apps/data-analytics/data/raw/Titanic-Dataset.csv"
df = pd.read_csv(path) 
df.columns=["passenger_id","survived","class","name","sex","age","sib_spouses","parents_children","ticket","fare","cabin","port"] 
df
# Out:
# C:\Users\cesar\AppData\Local\Temp\ipykernel_12684\3054679188.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#      passenger_id  survived  class  \
# 0               1         0      3
# 1               2         1      1
# 2               3         1      3
# 3               4         1      1
# 4               5         0      3
# ..            ...       ...    ...
# 886           887         0      2
# 887           888         1      1
# 888           889         0      3
# 889           890         1      1
# 890           891         0      3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   passenger_id      891 non-null    int64
#  1   survived          891 non-null    int64
#  2   class             891 non-null    int64
#  3   name              891 non-null    object
#  4   sex               891 non-null    object
#  5   age               714 non-null    float64
#  6   sib_spouses       891 non-null    int64
#  7   parents_children  891 non-null    int64
#  8   ticket            891 non-null    object
#  9   fare              891 non-null    float64
#  10  cabin             204 non-null    object
#  11  port              889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['passenger_id', 'survived', 'class', 'name', 'sex', 'age',
#        'sib_spouses', 'parents_children', 'ticket', 'fare', 'cabin', 'port'],
#       dtype='object')

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Histogramas

# %% [markdown]
# ### Histograma de sobrevivientes

# %%
df["survived"].plot(kind="hist",color="green")
plt.title("Sobrevivientes")
plt.xlabel('0 No sobrevivieron, 1 Sobrevivieron')
plt.ylabel('Pasajeros')
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# Como podemos ver la mayoría de los pasajeros no sobrevivió, más de 500 murieron.

# %% [markdown]
# ### Histograma de clases del viaje

# %%
df["class"].plot(kind="hist",color="lightgreen")
plt.title("Clases del viaje")
plt.xlabel('Clases')
plt.ylabel('Pasajeros')
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# Como podemos visualizar en el histograma la clase en la que más pasajeros viajaban es en la tercera con aproximadamente 500 pasajeros

# %% [markdown]
# ### Histograma de sexo

# %%
df["sex"].hist(color="purple")
plt.title("Sexo")
plt.xlabel('sexo')
plt.ylabel('Pasajeros')
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# Se puede visualizar que había más pasajeros hombres que mujeres, con aproximadamente 570 hombres y aproximadamente 310 mujeres

# %% [markdown]
# ### Histograma de edad

# %%
df["age"].plot(kind="hist", color="lightblue")
plt.title("Edad")
plt.xlabel('Edad')
plt.ylabel('Pasajeros')
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# Como podemos ver en la gráfica la edad más frecuente es entre 17 y 25 años, con aproximadamente 175 pasajeros

# %% [markdown]
# ### Histograma de número de hermanos o esposos a bordo

# %%
df["sib_spouses"].plot(kind="hist", color="orange")
plt.title("# de hermanos o esposos a bordo")
plt.xlabel('# de hermanos o esposos  ')
plt.ylabel('Pasajeros')
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# En el histograma se puede ver que casi no habían hermanos o esposo a bordo, 600 no llevaban ni hermanos ni pareja

# %% [markdown]
# ### Histograma de número de padres e hijos a bordo

# %%
df["parents_children"].plot(kind="hist", color="yellow")
plt.title("# de padres e hijos a bordo")
plt.xlabel('# de padres e hijos  ')
plt.ylabel('Pasajeros')
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# Se puede visualizar que la mayortía de los pasajeros, aproximadamente 670 pasajeros no llevaban padres o hijos

# %% [markdown]
# ### Histograma de tarifa de pasajero

# %%
df["fare"].plot(kind="hist", color="pink")
plt.title("Tarifa de pasajero")
plt.xlabel('Tarifa')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# En el histograma se puede ver que la tarifa de la mayoría está aproximadamente entre la tarifa menor a 50 euros ya que la mayor clase que abordó fue la tercera de la tarifa con más de 700 pasajeros

# %% [markdown]
# ### Histograma de puertos

# %%
df["port"].hist(color="blue")
plt.title("Puertos")
plt.xlabel('Puertos')
plt.ylabel('Pasajeros')
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# El histograma muestra que el puerto donde abordaron más pasajeros fue en el S, después en el C y después en el Q
